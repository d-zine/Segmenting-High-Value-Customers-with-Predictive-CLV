# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter,StrMethodFormatter
from matplotlib.ticker import FormatStrFormatter
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import warnings
from pandas.core.common import SettingWithCopyWarning

# %%
portfolio = pd.read_json(r'C:\Desktop\portfolio.json', orient='records', lines=True)
profile = pd.read_json(r'C:\Desktop\profile.json', orient='records', lines=True)
transcript = pd.read_json(r'C:\Desktop\transcript.json', orient='records', lines=True)

# %%
df=pd.DataFrame(transcript['value'].values.tolist(),index=transcript.index)

# %%
transcript=transcript.merge(df,left_index=True, right_index=True)

# %%
#Day 1-15 Max Spender
transcript[transcript['person']=='ad1f0a409ae642bc9a43f31f56c130fc']
# Out:
#                                   person            event  \
# 7436    ad1f0a409ae642bc9a43f31f56c130fc   offer received
# 19410   ad1f0a409ae642bc9a43f31f56c130fc     offer viewed
# 25342   ad1f0a409ae642bc9a43f31f56c130fc      transaction
# 25343   ad1f0a409ae642bc9a43f31f56c130fc  offer completed
# 60639   ad1f0a409ae642bc9a43f31f56c130fc   offer received
# 78530   ad1f0a409ae642bc9a43f31f56c130fc     offer viewed
# 86391   ad1f0a409ae642bc9a43f31f56c130fc      transaction
# 118269  ad1f0a409ae642bc9a43f31f56c130fc   offer received
# 125692  ad1f0a409ae642bc9a43f31f56c130fc      transaction
# 125693  ad1f0a409ae642bc9a43f31f56c130fc  offer completed
# 149912  ad1f0a409ae642bc9a43f31f56c130fc     offer viewed
# 158089  ad1f0a409ae642bc9a43f31f56c130fc   offer received
# 169773  ad1f0a409ae642bc9a43f31f56c130fc     offer viewed
# 196148  ad1f0a409ae642bc9a43f31f56c130fc      transaction
# 196149  ad1f0a409ae642bc9a43f31f56c130fc  offer completed
# 209006  ad1f0a409ae642bc9a43f31f56c130fc   offer received
# 216737  ad1f0a409ae642bc9a43f31f56c130fc      transaction
# 229385  ad1f0a409ae642bc9a43f31f56c130fc     offer viewed
# 252552  ad1f0a409ae642bc9a43f31f56c130fc   offer received
#
#                                                     value  time  \
# 7436     {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0
# 19410    {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}    12
# 25342                                  {'amount': 575.23}    30
# 25343   {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...    30
# 60639    {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}   168
# 78530    {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}   192
# 86391                                    {'amount': 6.16}   216
# 118269   {'offer id': '2906b810c7d4411798c6938adc9daaa5'}   336
# 125692                                 {'amount': 641.21}   336
# 125693  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...   336
# 149912   {'offer id': '2906b810c7d4411798c6938adc9daaa5'}   402
# 158089   {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}   408
# 169773   {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}   414
# 196148                                  {'amount': 13.72}   480
# 196149  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...   480
# 209006   {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   504
# 216737                                  {'amount': 21.87}   504
# 229385   {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}   528
# 252552   {'offer id': '3f207df678b143eea3cee63160fa8bed'}   576
#
#                                 offer id  amount  \
# 7436    4d5c57ea9a6940dd891ad53e9dbe8da0     NaN
# 19410   4d5c57ea9a6940dd891ad53e9dbe8da0     NaN
# 25342                                NaN  575.23
# 25343                                NaN     NaN
# 60639   4d5c57ea9a6940dd891ad53e9dbe8da0     NaN
# 78530   4d5c57ea9a6940dd891ad53e9dbe8da0     NaN
# 86391                                NaN    6.16
# 118269  2906b810c7d4411798c6938adc9daaa5     NaN
# 125692                               NaN  641.21
# 125693                               NaN     NaN
# 149912  2906b810c7d4411798c6938adc9daaa5     NaN
# 158089  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN
# 169773  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN
# 196148                               NaN   13.72
# 196149                               NaN     NaN
# 209006  5a8bc65990b245e5a138643cd4eb9837     NaN
# 216737                               NaN   21.87
# 229385  5a8bc65990b245e5a138643cd4eb9837     NaN
# 252552  3f207df678b143eea3cee63160fa8bed     NaN
#
#                                 offer_id  reward
# 7436                                 NaN     NaN
# 19410                                NaN     NaN
# 25342                                NaN     NaN
# 25343   4d5c57ea9a6940dd891ad53e9dbe8da0    10.0
# 60639                                NaN     NaN
# 78530                                NaN     NaN
# 86391                                NaN     NaN
# 118269                               NaN     NaN
# 125692                               NaN     NaN
# 125693  2906b810c7d4411798c6938adc9daaa5     2.0
# 149912                               NaN     NaN
# 158089                               NaN     NaN
# 169773                               NaN     NaN
# 196148                               NaN     NaN
# 196149  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0
# 209006                               NaN     NaN
# 216737                               NaN     NaN
# 229385                               NaN     NaN
# 252552                               NaN     NaN

# %%
#Day 16-30 Max Spender
transcript[transcript['person']=='73afdeca19e349b98f09e928644610f8']
# Out:
#                                   person            event  \
# 45007   73afdeca19e349b98f09e928644610f8      transaction
# 60766   73afdeca19e349b98f09e928644610f8   offer received
# 118396  73afdeca19e349b98f09e928644610f8   offer received
# 131773  73afdeca19e349b98f09e928644610f8     offer viewed
# 142774  73afdeca19e349b98f09e928644610f8      transaction
# 142775  73afdeca19e349b98f09e928644610f8  offer completed
# 142776  73afdeca19e349b98f09e928644610f8  offer completed
# 148240  73afdeca19e349b98f09e928644610f8      transaction
# 158215  73afdeca19e349b98f09e928644610f8   offer received
# 165920  73afdeca19e349b98f09e928644610f8     offer viewed
# 169806  73afdeca19e349b98f09e928644610f8      transaction
# 169807  73afdeca19e349b98f09e928644610f8  offer completed
# 209136  73afdeca19e349b98f09e928644610f8   offer received
# 216789  73afdeca19e349b98f09e928644610f8      transaction
# 216790  73afdeca19e349b98f09e928644610f8  offer completed
# 252675  73afdeca19e349b98f09e928644610f8   offer received
# 267529  73afdeca19e349b98f09e928644610f8      transaction
# 267530  73afdeca19e349b98f09e928644610f8  offer completed
# 276096  73afdeca19e349b98f09e928644610f8     offer viewed
# 280882  73afdeca19e349b98f09e928644610f8      transaction
# 285157  73afdeca19e349b98f09e928644610f8      transaction
# 297312  73afdeca19e349b98f09e928644610f8      transaction
# 301393  73afdeca19e349b98f09e928644610f8      transaction
#
#                                                     value  time  \
# 45007                                   {'amount': 32.72}   114
# 60766    {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}   168
# 118396   {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}   336
# 131773   {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}   348
# 142774                                  {'amount': 26.66}   378
# 142775  {'offer_id': '0b1e1539f2cc45b7b9fa7c272da2e1d7...   378
# 142776  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...   378
# 148240                                  {'amount': 14.86}   396
# 158215   {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}   408
# 165920   {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}   408
# 169806                                 {'amount': 516.89}   414
# 169807  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...   414
# 209136   {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}   504
# 216789                                  {'amount': 25.32}   504
# 216790  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...   504
# 252675   {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}   576
# 267529                                  {'amount': 34.64}   588
# 267530  {'offer_id': '2298d6c36e964ae4a3e7e9706d1fb8c2...   588
# 276096   {'offer id': '2298d6c36e964ae4a3e7e9706d1fb8c2'}   606
# 280882                                  {'amount': 26.23}   618
# 285157                                 {'amount': 597.91}   630
# 297312                                  {'amount': 21.13}   672
# 301393                                  {'amount': 23.61}   690
#
#                                 offer id  amount  \
# 45007                                NaN   32.72
# 60766   0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN
# 118396  fafdcd668e3743c1bb461111dcafc2a4     NaN
# 131773  fafdcd668e3743c1bb461111dcafc2a4     NaN
# 142774                               NaN   26.66
# 142775                               NaN     NaN
# 142776                               NaN     NaN
# 148240                               NaN   14.86
# 158215  fafdcd668e3743c1bb461111dcafc2a4     NaN
# 165920  fafdcd668e3743c1bb461111dcafc2a4     NaN
# 169806                               NaN  516.89
# 169807                               NaN     NaN
# 209136  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN
# 216789                               NaN   25.32
# 216790                               NaN     NaN
# 252675  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN
# 267529                               NaN   34.64
# 267530                               NaN     NaN
# 276096  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN
# 280882                               NaN   26.23
# 285157                               NaN  597.91
# 297312                               NaN   21.13
# 301393                               NaN   23.61
#
#                                 offer_id  reward
# 45007                                NaN     NaN
# 60766                                NaN     NaN
# 118396                               NaN     NaN
# 131773                               NaN     NaN
# 142774                               NaN     NaN
# 142775  0b1e1539f2cc45b7b9fa7c272da2e1d7     5.0
# 142776  fafdcd668e3743c1bb461111dcafc2a4     2.0
# 148240                               NaN     NaN
# 158215                               NaN     NaN
# 165920                               NaN     NaN
# 169806                               NaN     NaN
# 169807  fafdcd668e3743c1bb461111dcafc2a4     2.0
# 209136                               NaN     NaN
# 216789                               NaN     NaN
# 216790  9b98b8c7a33c4b65b9aebfe6a799e6d9     5.0
# 252675                               NaN     NaN
# 267529                               NaN     NaN
# 267530  2298d6c36e964ae4a3e7e9706d1fb8c2     3.0
# 276096                               NaN     NaN
# 280882                               NaN     NaN
# 285157                               NaN     NaN
# 297312                               NaN     NaN
# 301393                               NaN     NaN
